# %% [markdown]
# # LinkedIn Scrapper

# %% [markdown]
# I use ScrapingDob API to scrap LinkedIn data science jobs from 7 different countries, each at which I scrap 100 jobs.

# %%
import requests
from pprint import pprint
import re
import pandas as pd
from tqdm import tqdm

# %%
API_KEY = 'YOUR API HERE'
geoids = ['100459316', # Saudi Arabia
          '104305776', # United Arab Emirates
          '106155005', # Egypt
          '102299470', # England
          '104738515', # Ireland
          '103644278', # United States
          '101174742', # Canada
          ] 
npages = list(range(1,5))

# %% [markdown]
# ### Calculating the number of API calls
#
# To get the jobs postings, every API call returns 25 postings per page per geoid. Number of geoids = 7, number of pages = 4, then the total number of API calls = $7 * 4 = 28$ calls.
#
# For each job posting, we need a separate API call to get the job details. This is $28 * 25 = 700$ calls. Then total number of calls = 728.
#
# We have a total of 1000 free API calls which I already used some of.

# %%
# Test
payload = {'api_key': API_KEY, 'field': 'data scientist', 'geoid': '100459316', 'page':'1'}
resp = requests.get('https://api.scrapingdog.com/linkedinjobs', params=payload)
pprint(resp.json())
# Out:
# [{'company_name': 'Halian',
#   'company_profile': 'https://uk.linkedin.com/company/halian?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/data-scientist-at-halian-3584041432?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=WRoLrM29YGLrOwJEsjx4Pw%3D%3D&position=1&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Riyadh, Riyadh, Saudi Arabia',
#   'job_position': 'Data Scientist',
#   'job_posting_date': '2023-03-30'},
#  {'company_name': 'Halian',
#   'company_profile': 'https://uk.linkedin.com/company/halian?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/data-science-specialist-at-halian-3608956611?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=OlXFOxgknw3%2FKCOwQANseA%3D%3D&position=2&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Riyadh, Riyadh, Saudi Arabia',
#   'job_position': 'Data Science Specialist',
#   'job_posting_date': '2023-05-16'},
#  {'company_name': 'Garima Interprises',
#   'job_link': 'https://sa.linkedin.com/jobs/view/data-scientist-job-recruitment-at-garima-interprises-3626306377?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=TTefBv9Xns7U17bEu3VojA%3D%3D&position=3&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Saudi Arabia',
#   'job_position': '',
#   'job_posting_date': '2023-05-11'},
#  {'company_name': 'Energy Jobline',
#   'company_profile': 'https://uk.linkedin.com/company/energy-jobline?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/data-scientist-engineer-at-energy-jobline-3651133334?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=EKj7Wc%2BJ3nCL22EmWzAg8w%3D%3D&position=4&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Makkah Region',
#   'job_position': 'Data Scientist Engineer',
#   'job_posting_date': '2023-06-07'},
#  {'company_name': 'Cobblestone Energy',
#   'company_profile': 'https://ae.linkedin.com/company/cobblestone-energy?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/junior-developer-dubai-uae-at-cobblestone-energy-3642306208?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=V%2FET%2FutlJx4rRpKHNBS4zw%3D%3D&position=5&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Riyadh, Riyadh, Saudi Arabia',
#   'job_position': 'JUNIOR DEVELOPER - Dubai, UAE',
#   'job_posting_date': '2023-06-22'},
#  {'company_name': 'Garima Interprises',
#   'job_link': 'https://sa.linkedin.com/jobs/view/data-scientist-job-recruitment-at-garima-interprises-3645495537?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=4Sg76xD1iEj0MNE0sPuiBQ%3D%3D&position=6&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Saudi Arabia',
#   'job_position': '',
#   'job_posting_date': '2023-06-02'},
#  {'company_name': 'Garima Interprises',
#   'job_link': 'https://sa.linkedin.com/jobs/view/data-scientist-job-recruitment-at-garima-interprises-3650667632?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=mrs%2BZhwquY7fZ%2F9NyfYbfQ%3D%3D&position=7&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Saudi Arabia',
#   'job_position': '',
#   'job_posting_date': '2023-06-06'},
#  {'company_name': 'Armaco Chemical Processes Systems Pvt Ltd',
#   'job_link': 'https://sa.linkedin.com/jobs/view/data-scientist-nlp-expert-artificial-intelligence-data-analytics-at-armaco-chemical-processes-systems-pvt-ltd-3614308774?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=BqH63VqBSG2IqurAN4KlMQ%3D%3D&position=8&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Jeddah, Makkah, Saudi Arabia',
#   'job_position': '',
#   'job_posting_date': '2023-05-02'},
#  {'company_name': 'Energy Jobline',
#   'company_profile': 'https://uk.linkedin.com/company/energy-jobline?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/upstream-data-analytics-scientist-at-energy-jobline-3629321442?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=UCixuzTpifU7jXSttRhuSA%3D%3D&position=9&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Makkah Region',
#   'job_position': 'Upstream Data Analytics Scientist',
#   'job_posting_date': '2023-06-07'},
#  {'company_name': 'Jobs for Humanity',
#   'company_profile': 'https://www.linkedin.com/company/jobs-for-humanity-global?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/data-scientist-at-jobs-for-humanity-3627679220?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=fiA%2FUfbsrBa1n%2FCJnUWLxg%3D%3D&position=10&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Riyadh, Riyadh, Saudi Arabia',
#   'job_position': 'Data Scientist',
#   'job_posting_date': '2023-06-06'},
#  {'company_name': 'Niharika Enterprises',
#   'job_link': 'https://sa.linkedin.com/jobs/view/hiring-for-data-scientist-at-niharika-enterprises-3646364989?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=EA7Hix%2BRCWvX6wJc6vQWPg%3D%3D&position=11&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Saudi Arabia',
#   'job_position': '',
#   'job_posting_date': '2023-06-03'},
#  {'company_name': 'nybl',
#   'company_profile': 'https://ae.linkedin.com/company/nybl?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/data-analyst-data-scientist-at-nybl-3598185449?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=aT0McUHKvm%2BGDu24V7Pvjw%3D%3D&position=12&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Al Khobar, Eastern, Saudi Arabia',
#   'job_position': 'Data Analyst / Data Scientist',
#   'job_posting_date': '2023-05-05'},
#  {'company_name': 'EPAM Systems',
#   'company_profile': 'https://www.linkedin.com/company/epam-systems?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/senior-lead-data-scientist-at-epam-systems-3647633719?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=Y3W0tOnANmKtJsfAQtBQoA%3D%3D&position=13&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Dammam, Eastern, Saudi Arabia',
#   'job_position': 'Senior/Lead Data Scientist',
#   'job_posting_date': '2023-06-29'},
#  {'company_name': 'nielsensports',
#   'job_link': 'https://sa.linkedin.com/jobs/view/data-scientist-at-nielsensports-3601411501?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=DbbHcCL4WA%2FZ%2F4oYGcwKQQ%3D%3D&position=14&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Jeddah, Makkah, Saudi Arabia',
#   'job_position': '',
#   'job_posting_date': '2023-05-12'},
#  {'company_name': 'Energy Jobline',
#   'company_profile': 'https://uk.linkedin.com/company/energy-jobline?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/downstream-data-scientist-at-energy-jobline-3629321456?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=V3Fm5YVk7qZikNCQCQtBVw%3D%3D&position=15&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Makkah Region',
#   'job_position': 'Downstream Data Scientist',
#   'job_posting_date': '2023-06-07'},
#  {'company_name': 'StatusNeo',
#   'company_profile': 'https://www.linkedin.com/company/statusneo?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/react-native-developer-at-statusneo-3597013213?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=6RuVTSwfbRNzOHWLDBQmhg%3D%3D&position=16&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Riyadh, Riyadh, Saudi Arabia',
#   'job_position': 'React Native Developer',
#   'job_posting_date': '2023-05-05'},
#  {'company_name': 'FNRCO',
#   'company_profile': 'https://sa.linkedin.com/company/first-national-co?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/integration-engineer-at-fnrco-3639352686?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=Ncbw1jhx%2B%2BDhMyly4HF5SA%3D%3D&position=17&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Umluj, Tabuk, Saudi Arabia',
#   'job_position': 'Integration Engineer',
#   'job_posting_date': '2023-06-18'},
#  {'company_name': 'Halian',
#   'company_profile': 'https://uk.linkedin.com/company/halian?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/data-science-ml-team-lead-at-halian-3608960036?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=yd8joeFkKagEiljcM44mRg%3D%3D&position=18&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Riyadh, Riyadh, Saudi Arabia',
#   'job_position': 'Data Science & ML Team Lead',
#   'job_posting_date': '2023-05-16'},
#  {'company_name': 'تام | TAM',
#   'company_profile': 'https://sa.linkedin.com/company/tam-development-llc?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/software-engineer-digital-solutions-at-%D8%AA%D8%A7%D9%85-tam-3636833283?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=Asktc6CY6KGDBugyLyBo4w%3D%3D&position=19&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Riyadh, Riyadh, Saudi Arabia',
#   'job_position': 'Software Engineer, Digital Solutions',
#   'job_posting_date': '2023-05-20'},
#  {'company_name': 'SDAIA | سدايا',
#   'company_profile': 'https://sa.linkedin.com/company/sdaia-ksa?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/cloud-engineer-at-sdaia-%D8%B3%D8%AF%D8%A7%D9%8A%D8%A7-3639176174?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=VFRAWmg4BG6jXVV0ZGoXlw%3D%3D&position=20&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Riyadh, Saudi Arabia',
#   'job_position': 'Cloud Engineer',
#   'job_posting_date': '2023-06-18'},
#  {'company_name': 'Armaco Chemical Processes Systems Pvt Ltd',
#   'job_link': 'https://sa.linkedin.com/jobs/view/data-scientist-at-armaco-chemical-processes-systems-pvt-ltd-3646243379?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=xiLNGIDgcNLnaathHjMpxA%3D%3D&position=21&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Jeddah, Makkah, Saudi Arabia',
#   'job_position': '',
#   'job_posting_date': '2023-06-06'},
#  {'company_name': 'Mozn',
#   'company_profile': 'https://sa.linkedin.com/company/mozn?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/software-engineer-at-mozn-3621925253?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=i2P5NDGOgnvLy%2BC66C7yMQ%3D%3D&position=22&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Riyadh, Riyadh, Saudi Arabia',
#   'job_position': 'Software Engineer',
#   'job_posting_date': '2023-05-29'},
#  {'company_name': 'Tata Communications Transformation Services (TCTS)',
#   'company_profile': 'https://in.linkedin.com/company/tata-tcts?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/sr-engineer-data-center-service-at-tata-communications-transformation-services-tcts-3637794660?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=64%2BL0hvLWk3xRyitUajrhA%3D%3D&position=23&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Jeddah, Makkah, Saudi Arabia',
#   'job_position': 'Sr. Engineer - Data center Service',
#   'job_posting_date': '2023-06-16'},
#  {'company_name': 'Arabic Computer Systems',
#   'company_profile': 'https://sa.linkedin.com/company/arabic-computer-systems?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/application-developer-at-arabic-computer-systems-3646122110?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=SfUaqBZURocC%2BduTJMQEaA%3D%3D&position=24&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Al Kharj, Riyadh, Saudi Arabia',
#   'job_position': 'Application developer',
#   'job_posting_date': '2023-06-01'},
#  {'company_name': 'MatchaTalent',
#   'company_profile': 'https://id.linkedin.com/company/matchatalent?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'job_link': 'https://sa.linkedin.com/jobs/view/data-science-ai-digitalization-specialist-at-matchatalent-3647162238?refId=i8jN%2BWhNllILFyMOLf85lw%3D%3D&trackingId=4ydp5uzlzAQEQ2sRhgDBYQ%3D%3D&position=25&pageNum=1&trk=public_jobs_jserp-result_search-card',
#   'job_location': 'Dhahran, Eastern, Saudi Arabia',
#   'job_position': 'Data Science AI Digitalization Specialist',
#   'job_posting_date': '2023-06-26'}]

# %%
jobs = resp.json()
print('Number of jobs:', len(jobs))
# Out:
# Number of jobs: 25

# %%
# Converting the returned JSON data to pandas DataFrames
jobs_df = pd.DataFrame(jobs)
jobs_df.head()
# Out:
#                     job_position  \
# 0                 Data Scientist
# 1        Data Science Specialist
# 2
# 3        Data Scientist Engineer
# 4  JUNIOR DEVELOPER - Dubai, UAE
#
#                                             job_link        company_name  \
# 0  https://sa.linkedin.com/jobs/view/data-scienti...              Halian
# 1  https://sa.linkedin.com/jobs/view/data-science...              Halian
# 2  https://sa.linkedin.com/jobs/view/data-scienti...  Garima Interprises
# 3  https://sa.linkedin.com/jobs/view/data-scienti...      Energy Jobline
# 4  https://sa.linkedin.com/jobs/view/junior-devel...  Cobblestone Energy
#
#                                      company_profile  \
# 0  https://uk.linkedin.com/company/halian?trk=pub...
# 1  https://uk.linkedin.com/company/halian?trk=pub...
# 2                                                NaN
# 3  https://uk.linkedin.com/company/energy-jobline...
# 4  https://ae.linkedin.com/company/cobblestone-en...
#
#                    job_location job_posting_date
# 0  Riyadh, Riyadh, Saudi Arabia       2023-03-30
# 1  Riyadh, Riyadh, Saudi Arabia       2023-05-16
# 2                  Saudi Arabia       2023-05-11
# 3                 Makkah Region       2023-06-07
# 4  Riyadh, Riyadh, Saudi Arabia       2023-06-22

# %%
jobs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   job_position      25 non-null     object
#  1   job_link          25 non-null     object
#  2   company_name      25 non-null     object
#  3   company_profile   18 non-null     object
#  4   job_location      25 non-null     object
#  5   job_posting_date  25 non-null     object
# dtypes: object(6)
# memory usage: 1.3+ KB

# %%
# Extracting the job id from the job posting URL
def get_job_id(job):
    try:
        id = re.findall('-(\d{10})\?', job['job_link'])[0]
    except:
        id = ''
    return id

get_job_id(jobs[0])
# Out:
# '3584041432'

# %% [markdown]
# ### Get the job postings for the given geoids and for the given number of pages

# %%
jobs_df = pd.DataFrame()    # Empty dataframe
for geoid in geoids:
    for page in npages:
        payload = {'api_key': API_KEY, 'field': 'data scientist', 'geoid': geoid, 'page': str(page)}
        resp = requests.get('https://api.scrapingdog.com/linkedinjobs', params=payload)
        jobs = pd.DataFrame(resp.json())
        if jobs_df.empty:
            jobs_df = jobs
        else:
            jobs_df = jobs_df.append(jobs, ignore_index=True)
print('Scrapping done.')
print('Scrapped dataframe shape is', jobs_df.shape)
jobs_df.to_csv('./data/jobs.csv', index=False)
# Out:
# Scrapping done.
# Scrapped dataframe shape is (700, 6)

# %%
# Adding a new columns storing the job id for each job
jobs_df['job_id'] = jobs_df.apply(get_job_id, axis=1)
jobs_df.sample(10).head(10)
# Out:
#                                  job_position  \
# 328                            Data Scientist
# 0                              Data Scientist
# 525                           Data Engineer 2
# 124
# 302                 Machine Learning Engineer
# 67                              Data engineer
# 238                  Senior Data Ops Engineer
# 103        Artificial Intelligence Specialist
# 137    Algorithm Developer with Rust (Remote)
# 115  JUNIOR DATA ANALYST - The Emirates Group
#
#                                               job_link  \
# 328  https://uk.linkedin.com/jobs/view/data-scienti...
# 0    https://sa.linkedin.com/jobs/view/data-scienti...
# 525  https://www.linkedin.com/jobs/view/data-engine...
# 124  https://ae.linkedin.com/jobs/view/data-analyst...
# 302  https://uk.linkedin.com/jobs/view/machine-lear...
# 67   https://sa.linkedin.com/jobs/view/data-enginee...
# 238  https://eg.linkedin.com/jobs/view/senior-data-...
# 103  https://ae.linkedin.com/jobs/view/artificial-i...
# 137  https://ae.linkedin.com/jobs/view/algorithm-de...
# 115  https://ae.linkedin.com/jobs/view/junior-data-...
#
#                  company_name  \
# 328  Altasu Recruitment Group
# 0                MatchaTalent
# 525              MyFitnessPal
# 124        Garima Interprises
# 302                    Kaedim
# 67    Arabic Computer Systems
# 238                 SSC Egypt
# 103           Arthur Lawrence
# 137                   Keyrock
# 115                Talent Pal
#
#                                        company_profile  \
# 328  https://uk.linkedin.com/company/altasu-recruit...
# 0    https://id.linkedin.com/company/matchatalent?t...
# 525  https://www.linkedin.com/company/myfitnesspal?...
# 124                                                NaN
# 302  https://www.linkedin.com/company/kaedim?trk=pu...
# 67   https://sa.linkedin.com/company/arabic-compute...
# 238  https://eg.linkedin.com/company/ssc-egypt?trk=...
# 103  https://www.linkedin.com/company/arthur-lawren...
# 137  https://be.linkedin.com/company/keyrock?trk=pu...
# 115  https://www.linkedin.com/company/talent-pal?tr...
#
#                                           job_location job_posting_date  \
# 328                Nottingham, England, United Kingdom       2023-06-18
# 0                       Dhahran, Eastern, Saudi Arabia       2023-06-18
# 525                                         Austin, TX       2023-05-30
# 124                 Dubai, Dubai, United Arab Emirates       2023-05-04
# 302                    London, England, United Kingdom       2023-04-28
# 67                      Al Kharj, Riyadh, Saudi Arabia       2023-04-03
# 238                                Cairo, Cairo, Egypt       2023-06-22
# 103                 Dubai, Dubai, United Arab Emirates       2023-05-26
# 137  Abu Dhabi, Abu Dhabi Emirate, United Arab Emir...       2023-04-26
# 115                 Dubai, Dubai, United Arab Emirates       2023-06-30
#
#          job_id
# 328  3639112591
# 0    3639381396
# 525  3641744063
# 124  3595394797
# 302  3591963105
# 67   3590313780
# 238  3643300043
# 103  3619142293
# 137  3588411402
# 115  3651833371

# %% [markdown]
# ## Get job description and job details

# %%
# Scraping the actual job pages
job_details_df = pd.DataFrame()
# jobid_mask = ~jobs_df['job_id'].isin(job_details_df['job_id'])
# last_jobid_index = jobs_df[last_jobid_mask].index[0]
# jobids = jobs_df['job_id'].loc[jobid_mask]
jobids = jobs_df['job_id']
for job_id in tqdm(jobids):
    payload = {'api_key': API_KEY, 'job_id': job_id}
    resp = requests.get('https://api.scrapingdog.com/linkedinjobs', params=payload)
    try:
        job_details = resp.json()[0]
        job_details['job_id'] = job_id
        if job_details_df.empty:
            job_details_df = pd.DataFrame([job_details])
        else:
            job_details_df = job_details_df.append(pd.DataFrame([job_details]))
    except:
        print('error:', resp.json())

print('Scrapping job details completed.')
print('Shape of scrapped details is', job_details_df.shape)
# Out:
#  34%|███▎      | 45/134 [03:15<30:06, 20.30s/it]
# error: {'message': 'Something went wrong, you will be not charged for this request. Please try again or if you keep getting this error please mail us at info@scrapingdog.com.', 'success': False, 'status': 504}
# 100%|██████████| 134/134 [12:11<00:00,  5.46s/it]
# Scrapping job details completed.
# Shape of scrapped details is (613, 14)

# %%
# Removing duplicate jobs
job_details_df.drop_duplicates(subset='job_id', inplace=True)
job_details_df.shape
# Out:
# (607, 14)

# %%
# Saving the detailed job pages
job_details_df.to_csv('./data/job_details.csv', index=False)

# %%
print('Job details shape is:', job_details_df.shape)
job_details_df.tail()
# Out:
# Job details shape is: (607, 14)
#                                   job_position  \
# 0                 Sr Software Engineer(Python)
# 0                            NLP Data Engineer
# 0                           Software Developer
# 0                       Software Engineer - AI
# 0  Senior Software Developer, Machine Learning
#
#                           job_location  company_name  \
# 0             Toronto, Ontario, Canada      Techedin
# 0                               Canada    Inworld AI
# 0             Toronto, Ontario, Canada      WizeHire
# 0  Vancouver, British Columbia, Canada  Timbre Games
# 0              Ottawa, Ontario, Canada       Kinaxis
#
#                                  company_linkedin_id job_posting_time  \
# 0  https://www.linkedin.com/company/techedinlabs?...     2 months ago
# 0  https://www.linkedin.com/company/inworld-ai?tr...      1 month ago
# 0  https://www.linkedin.com/company/wizehire?trk=...      1 month ago
# 0  https://ca.linkedin.com/company/timbre-games?t...      2 weeks ago
# 0  https://ca.linkedin.com/company/kinaxis?trk=pu...      2 weeks ago
#
#                                      job_description   Seniority_level  \
# 0  We are hiring for a Senior Software Engineer(P...  Mid-Senior level
# 0  Why Join InworldInworld is a developer platfor...    Not Applicable
# 0  Would you love to dive in and learn more about...       Entry level
# 0  Welcome to Timbre!We are Timbre Games (part of...  Mid-Senior level
# 0  At Kinaxis, who we are is grounded in our comm...  Mid-Senior level
#
#   Employment_type                            Job_function  \
# 0       Full-time  Engineering and Information Technology
# 0       Full-time                  Information Technology
# 0       Full-time  Engineering and Information Technology
# 0       Full-time  Engineering and Information Technology
# 0       Full-time  Engineering and Information Technology
#
#                              Industries  \
# 0                  Software Development
# 0                  Software Development
# 0  Technology, Information and Internet
# 0                  Software Development
# 0                  Software Development
#
#                                    recruiter_details  \
# 0    [{'recruiter_name': '', 'recruiter_title': ''}]
# 0  [{'recruiter_photo': 'https://media.licdn.com/...
# 0    [{'recruiter_name': '', 'recruiter_title': ''}]
# 0    [{'recruiter_name': '', 'recruiter_title': ''}]
# 0    [{'recruiter_name': '', 'recruiter_title': ''}]
#
#                                         similar_jobs  \
# 0  [{'job_position': 'Javascript Engineer (Canada...
# 0  [{'job_position': 'Javascript Engineer (Canada...
# 0  [{'job_position': 'Software Developer', 'job_c...
# 0  [{'job_position': 'Software Engineer, Platform...
# 0  [{'job_position': 'Software Engineer ( All Lev...
#
#                                   people_also_viewed      job_id
# 0  [{'job_position': 'Software Engineer', 'job_co...  3567017339
# 0  [{'job_position': 'Software Development Engine...  3442436280
# 0  [{'job_position': 'Industry X Software Develop...  3599982035
# 0  [{'job_position': 'Staff Software Engineer, Fr...  3590181627
# 0  [{'job_position': 'Software Engineer/Developer...  3598027379

# %%
# Filtering columns of the job_details_df to avoid duplicated column named after merging
right_cols = job_details_df.columns.difference(['job_position', 'job_location', 'company_name']).to_list()
right_cols
# Out:
# ['Employment_type',
#  'Industries',
#  'Job_function',
#  'Seniority_level',
#  'company_linkedin_id',
#  'job_description',
#  'job_id',
#  'job_posting_time',
#  'people_also_viewed',
#  'recruiter_details',
#  'similar_jobs']

# %%
# Merging the jobs and the job pages data
all_jobs = jobs_df.merge(job_details_df[right_cols], on='job_id')
print('Complete jobs shape is', all_jobs.shape)
all_jobs.head()
# Out:
# Complete jobs shape is (699, 17)
#               job_position                                           job_link  \
# 0           Data Scientist  https://sa.linkedin.com/jobs/view/data-scienti...
# 1  Data Science Specialist  https://sa.linkedin.com/jobs/view/data-science...
# 2                           https://sa.linkedin.com/jobs/view/data-scienti...
# 3                           https://sa.linkedin.com/jobs/view/data-scienti...
# 4  Data Scientist Engineer  https://sa.linkedin.com/jobs/view/data-scienti...
#
#          company_name                                    company_profile  \
# 0        MatchaTalent  https://id.linkedin.com/company/matchatalent?t...
# 1              Halian  https://uk.linkedin.com/company/halian?trk=pub...
# 2  Garima Interprises                                                NaN
# 3  Garima Interprises                                                NaN
# 4      Energy Jobline  https://uk.linkedin.com/company/energy-jobline...
#
#                      job_location job_posting_date      job_id  \
# 0  Dhahran, Eastern, Saudi Arabia       2023-06-18  3639381396
# 1    Riyadh, Riyadh, Saudi Arabia       2023-05-16  3608956611
# 2                    Saudi Arabia       2023-06-02  3645495537
# 3                    Saudi Arabia       2023-05-11  3626306377
# 4                   Makkah Region       2023-06-07  3651133334
#
#   Employment_type                     Industries  \
# 0       Full-time        Staffing and Recruiting
# 1       Full-time  IT Services and IT Consulting
# 2       Full-time        Staffing and Recruiting
# 3       Full-time        Staffing and Recruiting
# 4       Full-time        Staffing and Recruiting
#
#                              Job_function Seniority_level  \
# 0  Engineering and Information Technology     Entry level
# 1  Engineering and Information Technology     Entry level
# 2  Engineering and Information Technology     Entry level
# 3  Engineering and Information Technology     Entry level
# 4  Engineering and Information Technology     Entry level
#
#                                  company_linkedin_id  \
# 0  https://id.linkedin.com/company/matchatalent?t...
# 1  https://uk.linkedin.com/company/halian?trk=pub...
# 2                                                NaN
# 3                                                NaN
# 4  https://uk.linkedin.com/company/energy-jobline...
#
#                                      job_description job_posting_time  \
# 0  This role required candidate to permanently re...      2 weeks ago
# 1  Our ClientWe are partnered with one of the big...      1 month ago
# 2  We are looking to hire a highly creative data ...      1 month ago
# 3  We are looking to hire a highly creative data ...      1 month ago
# 4  Aramco energizes the world economy. Aramco occ...      3 weeks ago
#
#                                   people_also_viewed  \
# 0  [{'job_position': 'Data Scientist Job Recruitm...
# 1  [{'job_position': 'Cybersecurity Governance Sp...
# 2  [{'job_position': 'Junior Blockchain Developer...
# 3  [{'job_position': 'Relocate to the UK - Nurses...
# 4  [{'job_position': 'Senior Structural Engineer'...
#
#                                  recruiter_details  \
# 0  [{'recruiter_name': '', 'recruiter_title': ''}]
# 1  [{'recruiter_name': '', 'recruiter_title': ''}]
# 2  [{'recruiter_name': '', 'recruiter_title': ''}]
# 3  [{'recruiter_name': '', 'recruiter_title': ''}]
# 4  [{'recruiter_name': '', 'recruiter_title': ''}]
#
#                                         similar_jobs
# 0  [{'job_position': 'AI Engineer', 'job_company'...
# 1  [{'job_position': 'Senior Specialist M&A and I...
# 2  [{'job_position': 'Junior Python Developer (Re...
# 3  [{'job_position': 'Recruiter - Human Resources...
# 4  [{'job_position': 'Sr. Engineer - Data center ...

# %%
# Removing duplicated jobs after merging
all_jobs.drop_duplicates(subset='job_id', inplace=True)
all_jobs.reset_index(drop=True, inplace=True)
print('Complete jobs shape after removing duplicates is', all_jobs.shape)
all_jobs.head()
# Out:
# Complete jobs shape after removing duplicates is (607, 17)
#               job_position                                           job_link  \
# 0           Data Scientist  https://sa.linkedin.com/jobs/view/data-scienti...
# 1  Data Science Specialist  https://sa.linkedin.com/jobs/view/data-science...
# 2                           https://sa.linkedin.com/jobs/view/data-scienti...
# 3                           https://sa.linkedin.com/jobs/view/data-scienti...
# 4  Data Scientist Engineer  https://sa.linkedin.com/jobs/view/data-scienti...
#
#          company_name                                    company_profile  \
# 0        MatchaTalent  https://id.linkedin.com/company/matchatalent?t...
# 1              Halian  https://uk.linkedin.com/company/halian?trk=pub...
# 2  Garima Interprises                                                NaN
# 3  Garima Interprises                                                NaN
# 4      Energy Jobline  https://uk.linkedin.com/company/energy-jobline...
#
#                      job_location job_posting_date      job_id  \
# 0  Dhahran, Eastern, Saudi Arabia       2023-06-18  3639381396
# 1    Riyadh, Riyadh, Saudi Arabia       2023-05-16  3608956611
# 2                    Saudi Arabia       2023-06-02  3645495537
# 3                    Saudi Arabia       2023-05-11  3626306377
# 4                   Makkah Region       2023-06-07  3651133334
#
#   Employment_type                     Industries  \
# 0       Full-time        Staffing and Recruiting
# 1       Full-time  IT Services and IT Consulting
# 2       Full-time        Staffing and Recruiting
# 3       Full-time        Staffing and Recruiting
# 4       Full-time        Staffing and Recruiting
#
#                              Job_function Seniority_level  \
# 0  Engineering and Information Technology     Entry level
# 1  Engineering and Information Technology     Entry level
# 2  Engineering and Information Technology     Entry level
# 3  Engineering and Information Technology     Entry level
# 4  Engineering and Information Technology     Entry level
#
#                                  company_linkedin_id  \
# 0  https://id.linkedin.com/company/matchatalent?t...
# 1  https://uk.linkedin.com/company/halian?trk=pub...
# 2                                                NaN
# 3                                                NaN
# 4  https://uk.linkedin.com/company/energy-jobline...
#
#                                      job_description job_posting_time  \
# 0  This role required candidate to permanently re...      2 weeks ago
# 1  Our ClientWe are partnered with one of the big...      1 month ago
# 2  We are looking to hire a highly creative data ...      1 month ago
# 3  We are looking to hire a highly creative data ...      1 month ago
# 4  Aramco energizes the world economy. Aramco occ...      3 weeks ago
#
#                                   people_also_viewed  \
# 0  [{'job_position': 'Data Scientist Job Recruitm...
# 1  [{'job_position': 'Cybersecurity Governance Sp...
# 2  [{'job_position': 'Junior Blockchain Developer...
# 3  [{'job_position': 'Relocate to the UK - Nurses...
# 4  [{'job_position': 'Senior Structural Engineer'...
#
#                                  recruiter_details  \
# 0  [{'recruiter_name': '', 'recruiter_title': ''}]
# 1  [{'recruiter_name': '', 'recruiter_title': ''}]
# 2  [{'recruiter_name': '', 'recruiter_title': ''}]
# 3  [{'recruiter_name': '', 'recruiter_title': ''}]
# 4  [{'recruiter_name': '', 'recruiter_title': ''}]
#
#                                         similar_jobs
# 0  [{'job_position': 'AI Engineer', 'job_company'...
# 1  [{'job_position': 'Senior Specialist M&A and I...
# 2  [{'job_position': 'Junior Python Developer (Re...
# 3  [{'job_position': 'Recruiter - Human Resources...
# 4  [{'job_position': 'Sr. Engineer - Data center ...

# %%
all_jobs.to_csv('./data/full_jobs.csv', index=False)
